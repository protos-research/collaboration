# %% [markdown]
# # Features Extraction & Clustering. Part II.
# This part is focused on clustering inside top-levels clusters that were obtained in the previous part.

# %% [markdown]
# ## Preparing
#
# Firstly we have to re-run code of Part I before continue.

# %%
# Import of necessary libs and our classes
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.spatial.distance import squareform, pdist
from sklearn.cluster import DBSCAN
from cj_loader import Storer, Extractor, extract_features
import warnings
warnings.filterwarnings("ignore")

# Init storer object with given data and calculate precense of data
storer = Storer()
precense = storer.applicability()

# Calculation of data completeness matrix and weights
data_compl = storer.data_completeness()
weights = data_compl.mean().sort_values()

# transform boolean matrix to numeric
weighted = precense.copy()
for index, row in precense.iterrows():
    weighted.loc[index][:] = row * weights

# calculate distances between pairs of coins
distances = pd.DataFrame(squareform(pdist(weighted)), index=weighted.index, columns=weighted.index)

# Top-level clustering with DBSCAN algorithm
clustering = DBSCAN(eps=0.3, min_samples=3).fit(distances)
labels = clustering.labels_
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
print('Estimated number of clusters: %d' % n_clusters_)

# Clusters aggregation
weighted['label'] = labels
clusters = {}
for label in np.unique(labels):
    cl = weighted[weighted['label'] == label]
    clusters[label] = cl

# Extracting features
cl_coin_features = {}
unclustered_coins = set()
for label, cluster in clusters.items():
    if label != -1:
        cl_coin_features[label] = extract_features(storer, '2014-04-01', coins_set=cluster.index)
    else:
        unclustered_coins.update(cluster.index.values.tolist())
# Out:
# Estimated number of clusters: 4

# %% [markdown]
# ## Adjusting clustering parameters
#
# DBSCAN is one of the most common clustering algorithms and also most cited in scientific literature. It has a lot of advantages and widely recommended for various tasks. One of disatvantages of DBSCAN is routine of parameters selection, especially epsilon parameter. In the previous part DBSCAN was applied to data having all elements in \[0;1\] range. That simplified choosing of epsilon. Current clustering task is significantly more complicated. Parameters are non-normalized and have it's own scales. Number of parameters is pretty big so the task can be considered as high-dimensional clustering. High number of dimensions will also make direct clusters visualization impossible.
#
# Best possible approach to choose correct value for epsilon is to research results obtained with different values. Fortunately, such method was developed and described in several publications.
#
# [HDBSCAN](https://hdbscan.readthedocs.io/en/latest/index.html) - Hierarchical Density-Based Spatial Clustering of Applications with Noise. Performs DBSCAN over varying epsilon values and integrates the result to find a clustering that gives the best stability over epsilon. This allows HDBSCAN to find clusters of varying densities (unlike DBSCAN), and be more robust to parameter selection.

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
import hdbscan

for top_level_cl in range(n_clusters_):
    print("Top-level cluster: {}".format(top_level_cl))
    tc = cl_coin_features[top_level_cl]
    tc = tc.replace([np.inf, -np.inf], np.nan)
    tc = tc.dropna(axis='columns', how='any')
    print("shape: {}".format(tc.shape))
    clusterer = hdbscan.HDBSCAN(min_cluster_size=2)
    ll_labels = clusterer.fit_predict(tc)
    tc['label'] = ll_labels
    for label in np.unique(ll_labels):
        if label != -1:
            print('label %d' %label)
            cl = tc[tc['label'] == label]
            display(cl)
            print('-'*40)
        else:
            noise_coins = tc[tc['label'] == label].index.values.tolist()
            unclustered_coins.update(noise_coins)
            
    print('='*40) 
    
print("Unclustered coins:")
for co in unclustered_coins:
    print(co)
# Out:
# Top-level cluster: 0
# shape: (27, 95)
# label 0
#          active_address_mean  active_address_median  active_address_stddev  \
# vechain           949.394509                  699.5            1200.307321
# icon             1882.450161                 1056.0            1919.075742
#
#          active_address_skewns  active_address_kurtos  close_mean  \
# vechain               9.380132             127.998701    2.590254
# icon                  1.637988               1.567113    3.354226
#
#          close_median  close_stddev  close_skewns  close_kurtos  ...    \
# vechain          2.61      2.073741      0.348733     -0.837170  ...
# icon             2.67      2.305503      1.513255      1.962505  ...
#
#          trans_per_address_median  trans_per_address_stddev  \
# vechain              13806.638918              57591.330938
# icon                 15439.828774             555552.458802
#
#          trans_per_address_skewns  trans_per_address_kurtos  \
# vechain                 11.817810                172.859691
# icon                     9.788784                101.536048
#
#          tx_per_address_mean  tx_per_address_median  tx_per_address_stddev  \
# vechain             1.080835               1.081693               0.114190
# icon                1.067163               1.020315               0.210151
#
#          tx_per_address_skewns  tx_per_address_kurtos  label
# vechain              -0.055933               0.398785      0
# icon                  0.692688              -0.153612      0
#
# [2 rows x 96 columns]
# ----------------------------------------
# label 1
#               active_address_mean  active_address_median  \
# binance-coin           999.766234                  217.0
# omisego               3904.139896                 2467.5
#
#               active_address_stddev  active_address_skewns  \
# binance-coin            7791.168444              14.382106
# omisego                 8247.695864               6.691323
#
#               active_address_kurtos  close_mean  close_median  close_stddev  \
# binance-coin             226.810603    8.084689          9.26      5.893013
# omisego                   49.809485   10.894890          9.82      4.869719
#
#               close_skewns  close_kurtos  ...    trans_per_address_median  \
# binance-coin      0.043746     -1.360099  ...                 5051.448981
# omisego           0.360876      0.131471  ...                 7600.454755
#
#               trans_per_address_stddev  trans_per_address_skewns  \
# binance-coin              23890.993978                  6.502648
# omisego                   18506.548801                 13.566305
#
#               trans_per_address_kurtos  tx_per_address_mean  \
# binance-coin                 49.615987             1.082846
# omisego                     214.684558             1.375349
#
#               tx_per_address_median  tx_per_address_stddev  \
# binance-coin               1.062092               0.193961
# omisego                    1.256275               0.413903
#
#               tx_per_address_skewns  tx_per_address_kurtos  label
# binance-coin               0.827556               2.178119      1
# omisego                    4.556722              30.751261      1
#
# [2 rows x 96 columns]
# ----------------------------------------
# label 2
#                        active_address_mean  active_address_median  \
# power-ledger                   1779.313842                  450.0
# bytom                           657.467018                  446.0
# status                          987.235732                  620.0
# kyber-network                   936.940252                  516.0
# aion                            350.647059                  242.0
# rchain                           65.275304                   47.5
# funfair                         568.948052                  297.0
# loopring                        597.911111                  295.5
# waltonchain                     315.145553                  254.0
# augur                           456.766484                  377.0
# basic-attention-token           711.740566                  578.0
# 0x                              949.628571                  731.5
# qash                            259.127586                  184.0
# loom-network                    344.623288                  178.5
# kucoin-shares                   216.581121                   15.0
# populous                        449.096606                  368.0
# aelf                            410.696833                  257.0
# zilliqa                         730.729592                  596.5
# ethos                           323.564557                  278.0
# aeternity                       381.743902                  303.0
#
#                        active_address_stddev  active_address_skewns  \
# power-ledger                     3025.881014               2.281092
# bytom                             674.220442               3.584983
# status                           1383.104940               5.636902
# kyber-network                    1547.828189               4.638044
# aion                              410.546863               3.701675
# rchain                             74.429443               2.578367
# funfair                           630.972189               2.180213
# loopring                         1728.082395              12.963405
# waltonchain                       263.000883               3.737516
# augur                             323.064070               3.191605
# basic-attention-token             459.461106               1.679114
# 0x                                910.088532               5.975937
# qash                              227.125618               2.312331
# loom-network                      528.231459               3.539113
# kucoin-shares                    1513.373280              11.114239
# populous                          289.220522               2.592868
# aelf                             1106.880388              13.475649
# zilliqa                           817.031316               6.584975
# ethos                             208.521250               2.368344
# aeternity                         445.204151              10.060008
#
#                        active_address_kurtos  close_mean  close_median  \
# power-ledger                        4.219666    0.557741      0.447777
# bytom                              18.070853    0.362301      0.352443
# status                             39.888811    0.108137      0.075684
# kyber-network                      26.118587    1.784807      1.370000
# aion                               15.264639    2.691735      2.355000
# rchain                             13.607838    1.094281      1.050000
# funfair                             4.649262    0.039460      0.029683
# loopring                          200.276697    0.442309      0.362005
# waltonchain                        22.263249   11.364073      9.865000
# augur                              18.721484   20.261361     15.850000
# basic-attention-token               3.224670    0.272939      0.232911
# 0x                                 44.377914    0.769032      0.681018
# qash                                7.983496    0.764087      0.689685
# loom-network                       12.979001    0.261564      0.213449
# kucoin-shares                     144.287287    3.680672      2.990000
# populous                           11.805822   16.097421     11.455000
# aelf                              190.262334    1.091667      1.050000
# zilliqa                            52.120121    0.081106      0.071365
# ethos                               9.206586    2.256412      1.700000
# aeternity                         137.740200    1.595126      1.490000
#
#                        close_stddev  close_skewns  close_kurtos  ...    \
# power-ledger               0.340812      1.402221      1.785522  ...
# bytom                      0.247522      0.831446      0.245651  ...
# status                     0.098066      2.256887      6.333733  ...
# kyber-network              0.973657      1.425581      1.596338  ...
# aion                       1.888573      1.611819      3.118996  ...
# rchain                     0.678605      0.335606     -0.615536  ...
# funfair                    0.029096      2.533569      7.665132  ...
# loopring                   0.320652      1.410576      2.860271  ...
# waltonchain                7.509946      1.306660      1.939306  ...
# augur                     19.904376      1.715515      3.295499  ...
# basic-attention-token      0.138530      1.502049      2.643145  ...
# 0x                         0.522183      0.674149     -0.350680  ...
# qash                       0.423743      1.446614      2.546533  ...
# loom-network               0.144863      0.990261      0.248495  ...
# kucoin-shares              3.411707      2.522776      7.750430  ...
# populous                  15.257558      1.439948      1.470089  ...
# aelf                       0.451269      0.740229     -0.127404  ...
# zilliqa                    0.035365      0.969616      0.274079  ...
# ethos                      1.835292      1.707954      3.736363  ...
# aeternity                  1.120341      0.755745     -0.063445  ...
#
#                        trans_per_address_median  trans_per_address_stddev  \
# power-ledger                        4488.152524              11348.520879
# bytom                               6253.210601              38877.076001
# status                              5614.727056              11964.850609
# kyber-network                       5282.816318               7823.555497
# aion                                8500.707163             155013.764539
# rchain                              5708.825768             249371.808790
# funfair                             3075.443915              86043.307517
# loopring                            6045.900529              54846.934511
# waltonchain                         5928.113479              36809.795080
# augur                               5483.098352              15132.520550
# basic-attention-token               3606.849916              16218.547249
# 0x                                  6352.700854               4812.383183
# qash                                5886.808622              24812.639626
# loom-network                       14104.680415              15549.298573
# kucoin-shares                       1353.139363             964460.491300
# populous                            5537.818441               6190.729083
# aelf                               15626.563230              42210.151964
# zilliqa                            16241.574272              26118.927198
# ethos                               4224.490677               5869.650188
# aeternity                          10438.846669              10888.870015
#
#                        trans_per_address_skewns  trans_per_address_kurtos  \
# power-ledger                          13.554229                202.976926
# bytom                                 12.846367                184.142848
# status                                 8.577986                 92.223260
# kyber-network                          6.173834                 61.314781
# aion                                  13.618181                202.178100
# rchain                                11.218519                139.014991
# funfair                               14.154505                221.879295
# loopring                              17.270638                305.274743
# waltonchain                            9.292871                 92.056137
# augur                                  6.322831                 47.898602
# basic-attention-token                 12.561433                184.908063
# 0x                                     1.739028                  4.887285
# qash                                   6.688334                 49.751077
# loom-network                           1.813523                  5.567861
# kucoin-shares                         12.316858                155.735274
# populous                               1.694793                  3.006970
# aelf                                   6.545389                 53.551399
# zilliqa                                7.647189                 75.329836
# ethos                                  5.926127                 60.513508
# aeternity                              2.092658                  5.487425
#
#                        tx_per_address_mean  tx_per_address_median  \
# power-ledger                      1.070835               1.074252
# bytom                             1.102018               1.089468
# status                            1.408994               1.352601
# kyber-network                     1.205733               1.182190
# aion                              1.163089               1.126638
# rchain                            0.897106               0.902950
# funfair                           1.449644               1.233333
# loopring                          1.216407               1.154256
# waltonchain                       1.058315               1.048571
# augur                             1.385219               1.304811
# basic-attention-token             1.398750               1.241768
# 0x                                1.342820               1.288428
# qash                              1.018055               1.016605
# loom-network                      1.367727               1.353843
# kucoin-shares                     0.926963               0.869565
# populous                          1.216695               1.184783
# aelf                              1.499277               1.363958
# zilliqa                           1.400679               1.372200
# ethos                             1.043667               1.016506
# aeternity                         1.258172               1.223888
#
#                        tx_per_address_stddev  tx_per_address_skewns  \
# power-ledger                        0.330385               0.906042
# bytom                               0.171480               0.201866
# status                              0.354303               2.662188
# kyber-network                       0.199979               0.645657
# aion                                0.201389               1.502889
# rchain                              0.215825               0.848830
# funfair                             0.659184               2.553176
# loopring                            0.378954               3.585533
# waltonchain                         0.187528               3.197617
# augur                               0.451716               6.304069
# basic-attention-token               0.504844               4.077446
# 0x                                  0.342958               5.013044
# qash                                0.186535               0.067582
# loom-network                        0.455326               0.411909
# kucoin-shares                       0.341569               4.804123
# populous                            0.237509               6.244834
# aelf                                0.440857               1.578175
# zilliqa                             0.324885               0.265146
# ethos                               0.153906               0.727335
# aeternity                           0.202996               0.875744
#
#                        tx_per_address_kurtos  label
# power-ledger                        2.366292      2
# bytom                               1.945265      2
# status                             13.743134      2
# kyber-network                       0.061374      2
# aion                                4.640763      2
# rchain                              3.865996      2
# funfair                             7.034447      2
# loopring                           28.921042      2
# waltonchain                        25.541123      2
# augur                              48.630149      2
# basic-attention-token              23.229614      2
# 0x                                 33.697808      2
# qash                                0.897683      2
# loom-network                       -0.565459      2
# kucoin-shares                      34.968228      2
# populous                           68.613779      2
# aelf                                3.187754      2
# zilliqa                            -0.756347      2
# ethos                               1.039820      2
# aeternity                           0.982027      2
#
# [20 rows x 96 columns]
# ----------------------------------------
# ========================================
# Top-level cluster: 1
# shape: (61, 55)
# label 0
#                  close_mean  close_median  close_stddev  close_skewns  \
# bitcoin-private   23.240863        22.560     12.860430      1.261740
# hshare            11.814399         9.740      7.306931      1.559535
# bitcoin-diamond   14.807918         4.500     17.294688      1.481229
# maker            792.610902       781.930    322.325747      0.238778
# wanchain           4.423651         4.025      2.078610      0.705453
#
#                  close_kurtos   high_mean  high_median  high_stddev  \
# bitcoin-private      2.232808   25.634964       23.760    15.385629
# hshare               2.078288   12.823900       10.490     8.210162
# bitcoin-diamond      1.833662   17.134490        4.820    20.116470
# maker               -0.239704  837.310865      800.455   347.995799
# wanchain            -0.634565    4.682857        4.340     2.143479
#
#                  high_skewns  high_kurtos  ...    rate_btc_median  \
# bitcoin-private     1.464457     2.555959  ...           0.002917
# hshare              1.554403     1.961953  ...           0.001251
# bitcoin-diamond     1.460349     1.778262  ...           0.000492
# maker               0.361101    -0.123107  ...           0.086341
# wanchain            0.658691    -0.713747  ...           0.000533
#
#                  rate_btc_stddev  rate_btc_skewns  rate_btc_kurtos  \
# bitcoin-private         0.001316         1.137621         2.056149
# hshare                  0.001159         3.532915        14.703203
# bitcoin-diamond         0.001572         2.310487         6.983425
# maker                   0.027893        -0.549053         0.029306
# wanchain                0.000191         0.341138        -1.026182
#
#                  mcap_ratio_mean  mcap_ratio_median  mcap_ratio_stddev  \
# bitcoin-private         0.001502           0.001397           0.000807
# hshare                  0.001635           0.001264           0.001003
# bitcoin-diamond         0.001651           0.001442           0.000601
# maker                   0.001821           0.001697           0.000581
# wanchain                0.001700           0.001627           0.000809
#
#                  mcap_ratio_skewns  mcap_ratio_kurtos  label
# bitcoin-private           0.883645           0.207065      0
# hshare                    1.514419           2.000851      0
# bitcoin-diamond           1.048382          -0.029951      0
# maker                     0.909274           0.563056      0
# wanchain                  0.505815          -0.966857      0
#
# [5 rows x 56 columns]
# ----------------------------------------
# label 1
#        close_mean  close_median  close_stddev  close_skewns  close_kurtos  \
# ardor    0.248999      0.146666      0.360959      2.863432      8.456138
# steem    1.408093      1.070000      1.385575      1.503642      2.264808
#
#        high_mean  high_median  high_stddev  high_skewns  high_kurtos  ...    \
# ardor   0.269928     0.155014     0.404876     3.037440     9.818911  ...
# steem   1.520340     1.150000     1.496980     1.540028     2.428370  ...
#
#        rate_btc_median  rate_btc_stddev  rate_btc_skewns  rate_btc_kurtos  \
# ardor         0.000033         0.000025         1.839779         3.890813
# steem         0.000316         0.000859         3.948504        16.988578
#
#        mcap_ratio_mean  mcap_ratio_median  mcap_ratio_stddev  \
# ardor         0.000892           0.000529           0.001279
# steem         0.001109           0.000823           0.001216
#
#        mcap_ratio_skewns  mcap_ratio_kurtos  label
# ardor           2.871493           8.676248      1
# steem           1.600084           2.544892      1
#
# [2 rows x 56 columns]
# ----------------------------------------
# label 2
#               close_mean  close_median  close_stddev  close_skewns  \
# bytecoin-bcn    0.001071      0.000050      0.002226      3.862114
# bitshares       0.068236      0.007727      0.123098      2.921102
# siacoin         0.006439      0.000607      0.011083      3.222797
#
#               close_kurtos  high_mean  high_median  high_stddev  high_skewns  \
# bytecoin-bcn     26.673430   0.001157     0.000054     0.002402     3.689752
# bitshares        10.656447   0.072932     0.008211     0.132705     2.946530
# siacoin          14.875275   0.006968     0.000646     0.012276     3.443014
#
#               high_kurtos  ...    rate_btc_median  rate_btc_stddev  \
# bytecoin-bcn    22.428601  ...       9.970023e-08     2.660023e-07
# bitshares       10.692251  ...       1.797706e-05     2.180321e-05
# siacoin         17.092187  ...       7.107616e-07     1.341594e-06
#
#               rate_btc_skewns  rate_btc_kurtos  mcap_ratio_mean  \
# bytecoin-bcn         2.313100         6.036797         0.000677
# bitshares            1.976971         5.055244         0.000615
# siacoin              1.911383         3.867497         0.000708
#
#               mcap_ratio_median  mcap_ratio_stddev  mcap_ratio_skewns  \
# bytecoin-bcn           0.000030           0.001361           2.926192
# bitshares              0.000063           0.001122           2.914992
# siacoin                0.000038           0.001243           3.139076
#
#               mcap_ratio_kurtos  label
# bytecoin-bcn          10.582155      2
# bitshares             10.565782      2
# siacoin               14.080927      2
#
# [3 rows x 56 columns]
# ----------------------------------------
# label 3
#                       close_mean  close_median  close_stddev  close_skewns  \
# komodo                  2.420748       1.89000      2.236310      1.774483
# golem-network-tokens    0.298102       0.27422      0.226029      0.864060
# ark                     2.492056       2.45500      1.990124      1.088746
#
#                       close_kurtos  high_mean  high_median  high_stddev  \
# komodo                    3.604554   2.602976     2.000000     2.443241
# golem-network-tokens      0.875310   0.319904     0.292045     0.244917
# ark                       1.188183   2.684415     2.590000     2.160226
#
#                       high_skewns  high_kurtos  ...    rate_btc_median  \
# komodo                   1.910811     4.456263  ...           0.000341
# golem-network-tokens     0.913390     1.023700  ...           0.000051
# ark                      1.150835     1.356311  ...           0.000329
#
#                       rate_btc_stddev  rate_btc_skewns  rate_btc_kurtos  \
# komodo                       0.000169         0.446671        -0.131254
# golem-network-tokens         0.000049         1.739616         2.716876
# ark                          0.000176         0.976624         1.708981
#
#                       mcap_ratio_mean  mcap_ratio_median  mcap_ratio_stddev  \
# komodo                       0.000873           0.000672           0.000815
# golem-network-tokens         0.000883           0.000811           0.000657
# ark                          0.000864           0.000858           0.000684
#
#                       mcap_ratio_skewns  mcap_ratio_kurtos  label
# komodo                         1.799860           3.736237      3
# golem-network-tokens           0.848335           0.866487      3
# ark                            1.029220           1.032684      3
#
# [3 rows x 56 columns]
# ----------------------------------------
# label 4
#            close_mean  close_median  close_stddev  close_skewns  close_kurtos  \
# wax          0.401025      0.253520      0.476952      4.325298     28.728535
# digixdao    85.084494     59.435000    100.152757      1.760459      3.061513
# dentacoin    0.000574      0.000374      0.000725      3.900904     20.085688
#
#            high_mean  high_median  high_stddev  high_skewns  high_kurtos  \
# wax         0.464423     0.270466     0.611431     4.229268    24.002165
# digixdao   91.100699    63.560000   108.366901     1.796305     3.257511
# dentacoin   0.000660     0.000398     0.000929     4.605233    27.334378
#
#            ...    rate_btc_median  rate_btc_stddev  rate_btc_skewns  \
# wax        ...       2.754163e-05     3.106317e-05         3.446221
# digixdao   ...       1.754502e-02     1.035381e-02         1.912710
# dentacoin  ...       5.046969e-08     5.396153e-08         2.359340
#
#            rate_btc_kurtos  mcap_ratio_mean  mcap_ratio_median  \
# wax              17.315670         0.000700           0.000490
# digixdao          5.650685         0.000602           0.000429
# dentacoin         8.467067         0.000626           0.000423
#
#            mcap_ratio_stddev  mcap_ratio_skewns  mcap_ratio_kurtos  label
# wax                 0.000626           2.614212           8.014067      4
# digixdao            0.000703           1.728822           2.928424      4
# dentacoin           0.000832           3.695435          18.454049      4
#
# [3 rows x 56 columns]
# ----------------------------------------
# label 5
#                   close_mean  close_median  close_stddev  close_skewns  \
# cybermiles          0.209653      0.188085      0.098722      0.937930
# monaco              8.256865      7.500000      4.213411      0.593459
# zencash            22.862708     21.460000     14.165010      0.390113
# decentraland        0.086779      0.095550      0.050646     -0.012830
# dropil              0.005598      0.005720      0.000849     -0.516029
# bancor              3.660941      2.960000      2.398626      4.381781
# paypex              1.050470      1.010000      0.520715      0.350255
# polymath-network    0.623130      0.523797      0.286755      0.890957
# enigma-project      1.977663      1.720000      1.390260      1.493452
# moac                9.079839      9.260000      3.851052     -0.061420
# theta-token         0.164444      0.153641      0.043322      1.125320
# gxchain             3.393065      2.990000      1.471049      1.505856
# nuls                2.666116      2.590000      1.481698      0.532731
#
#                   close_kurtos  high_mean  high_median  high_stddev  \
# cybermiles            0.839453   0.226710     0.197038     0.110596
# monaco                0.441495   9.000823     8.130000     4.740944
# zencash              -0.735130  24.753895    22.990000    15.265151
# decentraland         -0.326775   0.094069     0.101427     0.055044
# dropil               -0.232788   0.006113     0.006088     0.001064
# bancor               28.189283   3.890000     3.055000     2.683823
# paypex               -0.444781   1.139421     1.095000     0.604531
# polymath-network      0.079759   0.674753     0.556775     0.319642
# enigma-project        2.804216   2.143620     1.860000     1.555507
# moac                 -1.001265   9.649731     9.840000     4.070448
# theta-token           0.825498   0.176060     0.163871     0.046669
# gxchain               3.375995   3.670428     3.250000     1.627804
# nuls                  0.794160   2.867961     2.730000     1.607618
#
#                   high_skewns  high_kurtos  ...    rate_btc_median  \
# cybermiles           1.017315     1.071018  ...       2.210712e-05
# monaco               0.730917     0.649901  ...       9.692494e-04
# zencash              0.431416    -0.647010  ...       2.919580e-03
# decentraland         0.124299     0.007083  ...       1.080277e-05
# dropil               0.264097     1.255825  ...       7.808254e-07
# bancor               4.263081    25.135643  ...       5.062960e-04
# paypex               1.470352     7.028575  ...       1.204651e-04
# polymath-network     0.871556    -0.089713  ...       6.517230e-05
# enigma-project       1.594281     2.992226  ...       2.182171e-04
# moac                -0.035481    -0.936430  ...       1.118302e-03
# theta-token          1.019619     0.493560  ...       1.807421e-05
# gxchain              1.688125     3.978809  ...       4.259065e-04
# nuls                 0.670237     1.117421  ...       3.170639e-04
#
#                   rate_btc_stddev  rate_btc_skewns  rate_btc_kurtos  \
# cybermiles           1.016537e-05         0.654467        -0.231995
# monaco               6.289680e-04         2.325042         7.927490
# zencash              9.794733e-04         0.225385        -0.418846
# decentraland         5.202075e-06        -0.290883        -1.107702
# dropil               1.437768e-07        -0.846285         0.018465
# bancor               7.255991e-04         8.139562        71.234417
# paypex               6.944378e-05         0.199130        -0.663339
# polymath-network     2.517043e-05         0.595057        -1.033858
# enigma-project       1.071887e-04         0.079450        -0.402444
# moac                 3.698108e-04         0.094831        -0.422601
# theta-token          5.205841e-06         0.911038         0.280574
# gxchain              3.383080e-04         2.763581         8.849582
# nuls                 1.485680e-04        -0.422798        -0.802625
#
#                   mcap_ratio_mean  mcap_ratio_median  mcap_ratio_stddev  \
# cybermiles               0.000416           0.000371           0.000202
# monaco                   0.000362           0.000329           0.000195
# zencash                  0.000253           0.000254           0.000175
# decentraland             0.000376           0.000369           0.000210
# dropil                   0.000370           0.000386           0.000060
# bancor                   0.000457           0.000397           0.000229
# paypex                   0.000258           0.000244           0.000120
# polymath-network         0.000539           0.000431           0.000243
# enigma-project           0.000518           0.000448           0.000363
# moac                     0.000518           0.000524           0.000114
# theta-token              0.000351           0.000334           0.000095
# gxchain                  0.000626           0.000599           0.000307
# nuls                     0.000361           0.000346           0.000134
#
#                   mcap_ratio_skewns  mcap_ratio_kurtos  label
# cybermiles                 0.562836          -0.763781      5
# monaco                     0.436356          -0.226983      5
# zencash                    0.127273          -1.272639      5
# decentraland               0.644192           0.732772      5
# dropil                    -0.779544          -0.361698      5
# bancor                     0.558214          -0.940856      5
# paypex                     0.403180          -0.388046      5
# polymath-network           0.899825          -0.084507      5
# enigma-project             1.487507           2.761826      5
# moac                       0.177664          -0.805532      5
# theta-token                0.909550           0.278834      5
# gxchain                    1.087165           2.750674      5
# nuls                       0.413765          -0.452485      5
#
# [13 rows x 56 columns]
# ----------------------------------------
# label 6
#                close_mean  close_median  close_stddev  close_skewns  \
# neoscoin         1.241401      0.057776      2.312290      3.161752
# crown            0.547453      0.011036      0.885053      1.936076
# korecoin         0.990036      0.029753      1.793782      1.970150
# maidsafecoin     0.170106      0.073602      0.206530      1.704730
# zcoin           21.557094     11.160000     25.684621      1.939066
# ion              1.123710      0.819653      1.119327      1.288495
# sibcoin          0.630847      0.161728      0.926206      2.157049
# emercoin         0.818447      0.224321      1.319319      2.477042
# blocknet         6.493587      0.121778     11.061462      1.786041
# bitsend          0.210375      0.005222      0.361271      2.010765
# transfercoin     0.502495      0.016246      0.857478      2.219602
# diamond          2.356839      0.293390      4.632165      2.946563
# monacoin         1.016929      0.074623      2.327473      3.473675
# exclusivecoin    0.350868      0.005140      0.624773      2.130950
# reddcoin         0.001280      0.000039      0.003109      3.698660
# monetaryunit     0.046694      0.000540      0.079685      2.313304
#
#                close_kurtos  high_mean  high_median  high_stddev  high_skewns  \
# neoscoin          13.667693   1.352071     0.061973     2.538932     3.183890
# crown              3.648528   0.597505     0.013560     0.962189     1.942499
# korecoin           3.236238   1.096288     0.035417     1.994462     2.001036
# maidsafecoin       3.147239   0.180155     0.076747     0.220148     1.735564
# zcoin              3.948439  23.088672    12.080000    27.740978     2.018183
# ion                1.640972   1.238601     0.891901     1.250366     1.479844
# sibcoin            5.283161   0.689684     0.171437     1.031382     2.251245
# emercoin           7.231048   0.878846     0.240944     1.427773     2.584766
# blocknet           2.636969   7.061386     0.135489    12.054517     1.802897
# bitsend            3.583548   0.230115     0.006082     0.398735     2.134792
# transfercoin       4.770671   0.554953     0.017823     0.943963     2.192058
# diamond            9.965001   2.547863     0.313869     5.053897     3.092576
# monacoin          14.141640   1.091220     0.081098     2.534999     3.656973
# exclusivecoin      4.916085   0.394431     0.005744     0.713081     2.276950
# reddcoin          17.764759   0.001403     0.000043     0.003454     3.825650
# monetaryunit       6.627993   0.051421     0.000615     0.088827     2.436268
#
#                high_kurtos  ...    rate_btc_median  rate_btc_stddev  \
# neoscoin         13.642464  ...       8.058983e-05     3.956990e-04
# crown             3.727477  ...       1.721539e-05     1.486377e-04
# korecoin          3.376039  ...       5.689136e-05     2.523717e-04
# maidsafecoin      3.272201  ...       8.949929e-05     5.166388e-05
# zcoin             4.440614  ...       3.109666e-03     1.836301e-03
# ion               2.814114  ...       2.372840e-04     1.089903e-04
# sibcoin           5.821812  ...       1.183304e-04     1.199335e-04
# emercoin          8.194776  ...       2.491345e-04     2.201666e-04
# blocknet          2.688300  ...       2.827746e-04     1.407655e-03
# bitsend           4.519553  ...       8.728452e-06     4.264147e-05
# transfercoin      4.537860  ...       3.742565e-05     8.104771e-05
# diamond          11.583995  ...       6.355228e-04     4.713165e-04
# monacoin         16.122038  ...       1.592230e-04     2.052980e-04
# exclusivecoin     5.975265  ...       9.489000e-06     8.654755e-05
# reddcoin         18.795357  ...       7.314169e-08     2.923602e-07
# monetaryunit      7.539260  ...       9.195411e-07     1.235955e-05
#
#                rate_btc_skewns  rate_btc_kurtos  mcap_ratio_mean  \
# neoscoin              2.431670         6.994469         0.000016
# crown                 1.497302         1.658155         0.000031
# korecoin              2.585461         8.747095         0.000007
# maidsafecoin          0.571676        -0.485515         0.000268
# zcoin                 0.482048        -0.204170         0.000292
# ion                   0.710750         1.881462         0.000072
# sibcoin               1.697724         4.689936         0.000035
# emercoin              0.715023        -0.003978         0.000117
# blocknet              1.468569         1.458448         0.000117
# bitsend               0.853146        -0.775657         0.000013
# transfercoin          0.994257         0.090049         0.000011
# diamond               1.508904         2.862232         0.000020
# monacoin              0.967236         0.427278         0.000196
# exclusivecoin         1.699690         2.789354         0.000005
# reddcoin              1.982224         3.152333         0.000128
# monetaryunit          1.367737         0.752221         0.000020
#
#                mcap_ratio_median  mcap_ratio_stddev  mcap_ratio_skewns  \
# neoscoin            6.995261e-07           0.000029           3.216032
# crown               4.047599e-07           0.000052           2.009594
# korecoin            1.768558e-07           0.000013           1.967379
# maidsafecoin        1.158692e-04           0.000326           1.713392
# zcoin               1.107759e-04           0.000366           1.598898
# ion                 4.541660e-05           0.000080           1.301249
# sibcoin             7.673365e-06           0.000052           2.194836
# emercoin            2.966228e-05           0.000191           2.453898
# blocknet            2.418933e-06           0.000194           1.720409
# bitsend             2.135303e-07           0.000023           2.033453
# transfercoin        3.047554e-07           0.000019           2.195006
# diamond             1.579299e-06           0.000042           2.943282
# monacoin            6.822043e-06           0.000463           3.365607
# exclusivecoin       8.749785e-08           0.000010           2.151703
# reddcoin            3.732510e-06           0.000311           3.679076
# monetaryunit        1.869393e-07           0.000034           2.192247
#
#                mcap_ratio_kurtos  label
# neoscoin               14.132880      6
# crown                   3.906457      6
# korecoin                3.194516      6
# maidsafecoin            3.191458      6
# zcoin                   2.311180      6
# ion                     1.369434      6
# sibcoin                 5.473870      6
# emercoin                6.974620      6
# blocknet                2.371543      6
# bitsend                 3.677086      6
# transfercoin            4.615749      6
# diamond                 9.895606      6
# monacoin               13.207020      6
# exclusivecoin           5.050775      6
# reddcoin               17.471926      6
# monetaryunit            5.862209      6
#
# [16 rows x 56 columns]
# ----------------------------------------
# ========================================
# Top-level cluster: 2
# shape: (3, 10)
# ========================================
# Top-level cluster: 3
# shape: (19, 106)
# label 0
#                   active_address_mean  active_address_median  \
# neo                       6186.555556                 5824.0
# ethereum-classic         10809.951152                10763.0
# bitcoin-gold             24770.355731                13296.0
#
#                   active_address_stddev  active_address_skewns  \
# neo                         6611.747396               1.372165
# ethereum-classic            8286.560932               0.689049
# bitcoin-gold               32325.900838               2.885266
#
#                   active_address_kurtos  close_mean  close_median  \
# neo                            3.604629   31.586522         20.12
# ethereum-classic               0.725340   12.379725         13.69
# bitcoin-gold                   9.292075  129.117545         84.71
#
#                   close_stddev  close_skewns  close_kurtos  ...    \
# neo                  39.027937      1.372236      1.261594  ...
# ethereum-classic     10.556761      0.660376     -0.279080  ...
# bitcoin-gold        103.964299      1.048445      0.166518  ...
#
#                   tx_per_address_median  tx_per_address_stddev  \
# neo                            2.196671               0.461210
# ethereum-classic               2.753299               1.736931
# bitcoin-gold                   0.225699               0.080849
#
#                   tx_per_address_skewns  tx_per_address_kurtos  \
# neo                            1.907444               6.457338
# ethereum-classic               1.205032               0.656309
# bitcoin-gold                  -0.072862               3.205795
#
#                   mdiff_to_volatility_mean  mdiff_to_volatility_median  \
# neo                               0.075625                    0.000000
# ethereum-classic                 17.226962                   12.174938
# bitcoin-gold                      0.565094                    0.502647
#
#                   mdiff_to_volatility_stddev  mdiff_to_volatility_skewns  \
# neo                                 0.924062                   19.345173
# ethereum-classic                   79.397441                   25.285356
# bitcoin-gold                        0.330306                    1.074817
#
#                   mdiff_to_volatility_kurtos  label
# neo                               409.596195      0
# ethereum-classic                  655.311219      0
# bitcoin-gold                        1.513131      0
#
# [3 rows x 107 columns]
# ----------------------------------------
# label 1
#           active_address_mean  active_address_median  active_address_stddev  \
# lisk              1256.345088                  845.5            1306.419742
# gas               4605.768519                 4411.5            5576.554873
# digibyte          7653.289331                 4285.0            7987.288277
# verge             4775.912040                  707.0            9105.175995
# zcash            53671.197802                56198.0           28965.458710
# waves             4530.174551                 3220.0            4783.672582
# dogecoin         44725.500591                35972.0           30990.339987
# pivx              2817.088009                 2696.0            1551.385042
# decred           10833.712222                11097.5            3816.079987
#
#           active_address_skewns  active_address_kurtos  close_mean  \
# lisk                   2.170264               8.431071    5.084455
# gas                    2.587282              15.329782   23.146736
# digibyte               2.910194              12.477327    0.007896
# verge                  2.395383               4.998431    0.011389
# zcash                  0.018248              -1.350792  233.724953
# waves                  2.243263               7.484182    3.155054
# dogecoin               2.850689              11.276300    0.001132
# pivx                   1.526174               8.624566    2.080260
# decred                 0.222284               0.659588   29.186445
#
#           close_median  close_stddev  close_skewns  close_kurtos  ...    \
# lisk          1.765000      7.069427      1.846910      2.940810  ...
# gas          20.590000     13.790248      1.121104      1.914183  ...
# digibyte      0.000279      0.016372      2.991550     11.571083  ...
# verge         0.000025      0.029746      3.755064     16.750922  ...
# zcash       220.800000    184.993409      3.025848     20.671637  ...
# waves         2.860000      3.291030      1.338110      1.970991  ...
# dogecoin      0.000243      0.001916      3.192562     13.440000  ...
# pivx          1.360000      2.711160      1.755510      3.364241  ...
# decred       15.510000     33.340191      0.980179     -0.305222  ...
#
#           tx_per_address_median  tx_per_address_stddev  tx_per_address_skewns  \
# lisk                   1.780763               0.396637               1.179027
# gas                    1.800429               0.809647               1.883398
# digibyte               0.640099               0.136387               0.030436
# verge                  0.701068               0.183204              -0.552401
# zcash                  0.096124               0.051123               5.473586
# waves                  2.522097               3.895967               2.982409
# dogecoin               0.445320               0.129465               0.957839
# pivx                   0.187977               0.169446               1.370168
# decred                 0.302313               0.072040               1.659293
#
#           tx_per_address_kurtos  mdiff_to_volatility_mean  \
# lisk                   2.528794                234.195165
# gas                    3.804189                 73.458813
# digibyte               2.460600               1334.301447
# verge                 -0.252065                950.513747
# zcash                 41.712232                  2.476253
# waves                 12.366264                 42.177654
# dogecoin               0.907888              37756.476612
# pivx                   3.121039                 41.565378
# decred                 9.949313                 59.520629
#
#           mdiff_to_volatility_median  mdiff_to_volatility_stddev  \
# lisk                      194.815368                  189.347875
# gas                         0.013154                  197.234739
# digibyte                  122.844788                 2645.075160
# verge                      33.238570                 7896.868751
# zcash                       1.655919                    3.959993
# waves                       4.054797                  159.940076
# dogecoin                24201.275609               332187.587638
# pivx                        1.146900                 1076.473628
# decred                      8.812540                  148.366603
#
#           mdiff_to_volatility_skewns  mdiff_to_volatility_kurtos  label
# lisk                        1.589927                    4.444137      1
# gas                         3.986829                   21.984833      1
# digibyte                    4.811180                   40.258149      1
# verge                      31.924672                 1099.745328      1
# zcash                       4.433368                   23.606822      1
# waves                       5.716705                   32.118045      1
# dogecoin                   40.333971                 1632.795528      1
# pivx                       29.339617                  858.875856      1
# decred                      5.126046                   33.825512      1
#
# [9 rows x 107 columns]
# ----------------------------------------
# label 2
#       active_address_mean  active_address_median  active_address_stddev  \
# nem            870.648026                  356.0            1267.603028
# dash         18778.626667                10335.0           17916.087571
#
#       active_address_skewns  active_address_kurtos  close_mean  close_median  \
# nem                4.200264              32.138797    0.131956      0.005698
# dash               2.149134              12.087689  120.214314      7.775000
#
#       close_stddev  close_skewns  close_kurtos  ...    tx_per_address_median  \
# nem       0.247699      3.310615     13.703799  ...                 1.634948
# dash    230.905655      2.654101      7.803201  ...                 0.170657
#
#       tx_per_address_stddev  tx_per_address_skewns  tx_per_address_kurtos  \
# nem               20.710297               7.254711              70.183217
# dash               0.158673               3.688645              26.213098
#
#       mdiff_to_volatility_mean  mdiff_to_volatility_median  \
# nem                6197.273077                 5089.033717
# dash                  8.365254                    3.932487
#
#       mdiff_to_volatility_stddev  mdiff_to_volatility_skewns  \
# nem                  7475.500598                   20.369103
# dash                   10.370287                    7.242054
#
#       mdiff_to_volatility_kurtos  label
# nem                   578.018261      2
# dash                  139.679172      2
#
# [2 rows x 107 columns]
# ----------------------------------------
# ========================================
# Unclustered coins:
# qtum
# cryptonex
# mixin
# kin
# stellar
# tether
# nano
# ripple
# huobi-token
# smartcash
# gifto
# mithril
# nxt
# elastos
# monero
# factom
# tron
# ethereum
# stratis
# tezos
# bitcoin
# iota
# veritaseum
# ontology
# litecoin
# pundi-x
# iostoken
# bitcoin-cash
# eos
# nebulas-token
# cardano
# tenx

# %% [markdown]
# ## Important notes
# ### Approach limitations
# Implemented approach is very general. It doesn't detect any mutual dependencies, following trends and other complex things. So it should be considered as clustering by basic time series characteristics. Particularly, top-level clustering is rather necessary measure then usual taken step. List of features describing each time serie is quite short, but it can easily be extended with additional features.
# ### Label "-1"
# HDBSCAN (as extension of DBSCAN method) groups together points that are closely packed together (points with many nearby neighbors), marking as outliers points that lie alone in low-density regions (whose nearest neighbors are too far away). This leads to appearing a section named "Unclustered coins" which includes these outliers belonging to -1 label. This list consists of two types of coins: coins with big amount of data missed and **real** outliers. Each coin presented in this list should be considered as **special**. it's not surprising, therefore, that couple of crypto-headliners appeared there: they are really outliers by many of parameters.
# ### Metrics
# HDBSCAN [can use different metrics][0] to calculate distance between coins by their values of features. The case examined uses default Euclidean metrics. Main disadvantage of such metrics is assumption that different parameters equally influence the distance. That actually is not true. The question of choosing metrics for high-dimensional clustering is [very][1] [controversial][2]. Generally one of the best ways is to define weight for each feature and use weighted Euclidean distance. Possibly this can be the theme of separate (and pretty complex) research.
# ### Methods
# Of course there are a lot of clustering algorithms nowadays that can be applied for this task instead of (H)DBSCAN. But most probably, applying of described approach to data splitted by timeframes of different market states as well as widening feature-sets extraction method can deliver more significant results. Next proposed step is switching to tsfresh library for automated features extraction.
# [0]:https://hdbscan.readthedocs.io/en/latest/basic_hdbscan.html#what-about-different-metrics
# [1]:https://www.researchgate.net/post/What_is_the_best_distance_measure_for_high_dimensional_data
# [2]:https://stats.stackexchange.com/questions/99171/why-is-euclidean-distance-not-a-good-metric-in-high-dimensions

# %% [markdown]
# # Clustering using automated features extraction technique
# Module tsfresh is used to to extract characteristics from time series. Actual version for the moment extracts ~800 features out of the box. Since our data consists of 22 series for each coin (15 from csv files and 7 additionally constructed), total number of features describing each coin is 17468. This time the task dimensionality becomes even more higher.
#
# ## Preparing data
# Tsfresh has [it's own format][1] of pandas.Dataframe() that should be used for features extraction. Since tsfresh [can easily handle][2] time series of unequal length, we can use **Storer.mf** containing the data across all coins, without using **Extractor** class for each coin separately. Additional method **tsfresh_format()** was implemented as @property of **Storer** class. This method converts mainframe to format compatible with tsfresh.
#
# [1]:https://tsfresh.readthedocs.io/en/latest/text/data_formats.html
# [2]:https://tsfresh.readthedocs.io/en/latest/text/faq.html

# %%
# Import of tsfresh methods
from tsfresh import extract_features as tsf_ef
from tsfresh.utilities.dataframe_functions import impute

# %%
# %%time

# Convert mainframe to format compatible with tsfresh
ts_df = storer.tsfresh_format

display(ts_df.head(10))
display(ts_df.tail(10))
# Out:
#            id            kind       time   value
# 1232  vechain  active_address 2017-08-15    2.00
# 1233  vechain  active_address 2017-08-16  159.25
# 1234  vechain  active_address 2017-08-17  316.50
# 1235  vechain  active_address 2017-08-18  473.75
# 1236  vechain  active_address 2017-08-19  631.00
# 1237  vechain  active_address 2017-08-20  205.00
# 1238  vechain  active_address 2017-08-21  393.00
# 1239  vechain  active_address 2017-08-22  296.00
# 1240  vechain  active_address 2017-08-23  470.00
# 1241  vechain  active_address 2017-08-24  456.00
#                 id            kind       time     value
# 3989174  aeternity  tx_per_address 2018-07-17  1.266904
# 3989175  aeternity  tx_per_address 2018-07-18  1.435262
# 3989176  aeternity  tx_per_address 2018-07-19  1.121864
# 3989177  aeternity  tx_per_address 2018-07-20  1.053191
# 3989178  aeternity  tx_per_address 2018-07-21  1.116022
# 3989179  aeternity  tx_per_address 2018-07-22  1.010638
# 3989180  aeternity  tx_per_address 2018-07-23  1.643068
# 3989181  aeternity  tx_per_address 2018-07-24  1.230769
# 3989182  aeternity  tx_per_address 2018-07-25  1.405858
# 3989183  aeternity  tx_per_address 2018-07-26  1.080169
# Wall time: 3min 32s

# %% [markdown]
# ## Features extraction
# Run process of automated features extraction with tsfresh and save the result to csv file.

# %%
# %%time

extracted_features = tsf_ef(ts_df, column_id="id", column_sort="time", column_kind="kind", column_value="value")
extracted_features = impute(extracted_features)
extracted_features.to_csv("ef.csv")  # Save it because it takes too long to calculate it each time
# Out:
# Feature Extraction: 100%|████████████████████████████████████████████████████████| 20/20 [26:14<00:00, 78.70s/it]
# Wall time: 26min 30s

# %%
# Show the structure of dataframe with extracted features
display(extracted_features.head(10))
display(extracted_features.tail(10))
# Out:
# variable               active_address__abs_energy  \
# id
# 0x                                   6.055194e+08
# aelf                                 3.080422e+08
# aeternity                            1.128107e+08
# aion                                 8.424410e+07
# ardor                                2.608398e+09
# ark                                  2.608398e+09
# augur                                1.139342e+08
# bancor                               2.608398e+09
# basic-attention-token                3.042960e+08
# binance-coin                         2.375521e+10
#
# variable               active_address__absolute_sum_of_changes  \
# id
# 0x                                                     82731.0
# aelf                                                   73441.0
# aeternity                                              41060.0
# aion                                                   54263.0
# ardor                                                 259974.0
# ark                                                   259974.0
# augur                                                  43618.0
# bancor                                                259974.0
# basic-attention-token                                  62326.0
# binance-coin                                          317075.0
#
# variable               active_address__agg_autocorrelation__f_agg_"mean"  \
# id
# 0x                                                              0.117297
# aelf                                                           -0.004179
# aeternity                                                       0.037174
# aion                                                            0.065037
# ardor                                                           0.340423
# ark                                                             0.340423
# augur                                                           0.350662
# bancor                                                          0.340423
# basic-attention-token                                           0.530526
# binance-coin                                                    0.015680
#
# variable               active_address__agg_autocorrelation__f_agg_"median"  \
# id
# 0x                                                              0.106349
# aelf                                                           -0.004811
# aeternity                                                       0.020251
# aion                                                            0.052556
# ardor                                                           0.353796
# ark                                                             0.353796
# augur                                                           0.394984
# bancor                                                          0.353796
# basic-attention-token                                           0.557664
# binance-coin                                                   -0.009919
#
# variable               active_address__agg_autocorrelation__f_agg_"var"  \
# id
# 0x                                                             0.027818
# aelf                                                           0.000163
# aeternity                                                      0.009742
# aion                                                           0.012044
# ardor                                                          0.010806
# ark                                                            0.010806
# augur                                                          0.021014
# bancor                                                         0.010806
# basic-attention-token                                          0.029372
# binance-coin                                                   0.011063
#
# variable               active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"  \
# id
# 0x                                                           2365.457143
# aelf                                                         3102.913043
# aeternity                                                    1155.857398
# aion                                                          968.441379
# ardor                                                        1238.273728
# ark                                                          1238.273728
# augur                                                         966.594595
# bancor                                                       1238.273728
# basic-attention-token                                        1202.082452
# binance-coin                                                 2513.285897
#
# variable               active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"rvalue"  \
# id
# 0x                                                             -0.336061
# aelf                                                           -0.295909
# aeternity                                                      -0.189691
# aion                                                            0.002184
# ardor                                                          -0.057492
# ark                                                            -0.057492
# augur                                                          -0.204435
# bancor                                                         -0.057492
# basic-attention-token                                          -0.136181
# binance-coin                                                    0.057883
#
# variable               active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope"  \
# id
# 0x                                                            -47.954622
# aelf                                                         -142.015810
# aeternity                                                     -22.828209
# aion                                                            0.232020
# ardor                                                          -6.645122
# ark                                                            -6.645122
# augur                                                         -11.882883
# bancor                                                         -6.645122
# basic-attention-token                                          -6.645122
# binance-coin                                                  108.372267
#
# variable               active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"stderr"  \
# id
# 0x                                                             23.395524
# aelf                                                          100.039258
# aeternity                                                      21.222047
# aion                                                           20.441058
# ardor                                                          36.135563
# ark                                                            36.135563
# augur                                                           9.617490
# bancor                                                         36.135563
# basic-attention-token                                           7.549721
# binance-coin                                                  307.281956
#
# variable               active_address__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept"  \
# id
# 0x                                                           5323.250000
# aelf                                                        10451.800000
# aeternity                                                    3799.857143
# aion                                                         2087.619048
# ardor                                                        3664.750000
# ark                                                          3664.750000
# augur                                                        1601.666667
# bancor                                                       3664.750000
# basic-attention-token                                        1849.844444
# binance-coin                                                13393.916667
#
# variable                                    ...                         \
# id                                          ...
# 0x                                          ...
# aelf                                        ...
# aeternity                                   ...
# aion                                        ...
# ardor                                       ...
# ark                                         ...
# augur                                       ...
# bancor                                      ...
# basic-attention-token                       ...
# binance-coin                                ...
#
# variable               volume__time_reversal_asymmetry_statistic__lag_1  \
# id
# 0x                                                        -1.052709e+21
# aelf                                                      -8.534993e+21
# aeternity                                                  2.524027e+20
# aion                                                      -2.047757e+20
# ardor                                                     -9.176908e+20
# ark                                                       -5.432228e+19
# augur                                                     -2.457617e+21
# bancor                                                     1.982417e+20
# basic-attention-token                                     -4.413956e+20
# binance-coin                                               4.497641e+21
#
# variable               volume__time_reversal_asymmetry_statistic__lag_2  \
# id
# 0x                                                        -6.852882e+20
# aelf                                                      -2.320098e+22
# aeternity                                                 -5.652238e+19
# aion                                                      -2.205417e+20
# ardor                                                     -2.808596e+21
# ark                                                       -7.823966e+18
# augur                                                     -3.936387e+20
# bancor                                                     1.819819e+20
# basic-attention-token                                      1.549729e+20
# binance-coin                                              -8.759933e+22
#
# variable               volume__time_reversal_asymmetry_statistic__lag_3  \
# id
# 0x                                                        -2.590628e+19
# aelf                                                      -4.200120e+22
# aeternity                                                 -7.643957e+20
# aion                                                      -1.225549e+20
# ardor                                                     -3.516748e+21
# ark                                                        6.011114e+19
# augur                                                     -1.350774e+21
# bancor                                                    -2.060632e+18
# basic-attention-token                                      1.207532e+20
# binance-coin                                              -6.003704e+22
#
# variable               volume__value_count__value_-inf  \
# id
# 0x                                                 0.0
# aelf                                               0.0
# aeternity                                          0.0
# aion                                               0.0
# ardor                                              0.0
# ark                                                0.0
# augur                                              0.0
# bancor                                             0.0
# basic-attention-token                              0.0
# binance-coin                                       0.0
#
# variable               volume__value_count__value_0  \
# id
# 0x                                              0.0
# aelf                                            0.0
# aeternity                                       0.0
# aion                                            0.0
# ardor                                           9.0
# ark                                             0.0
# augur                                           1.0
# bancor                                          0.0
# basic-attention-token                           0.0
# binance-coin                                    0.0
#
# variable               volume__value_count__value_1  \
# id
# 0x                                              0.0
# aelf                                            0.0
# aeternity                                       0.0
# aion                                            0.0
# ardor                                           1.0
# ark                                             0.0
# augur                                           2.0
# bancor                                          0.0
# basic-attention-token                           0.0
# binance-coin                                    0.0
#
# variable               volume__value_count__value_inf  \
# id
# 0x                                                0.0
# aelf                                              0.0
# aeternity                                         0.0
# aion                                              0.0
# ardor                                             0.0
# ark                                               0.0
# augur                                             0.0
# bancor                                            0.0
# basic-attention-token                             0.0
# binance-coin                                      0.0
#
# variable               volume__value_count__value_nan  volume__variance  \
# id
# 0x                                                0.0      3.565607e+14
# aelf                                              0.0      2.931632e+15
# aeternity                                         0.0      1.330522e+14
# aion                                              0.0      6.144918e+13
# ardor                                             0.0      2.289649e+14
# ark                                               0.0      4.445506e+13
# augur                                             0.0      1.510852e+14
# bancor                                            0.0      5.326489e+13
# basic-attention-token                             0.0      1.318699e+14
# binance-coin                                      0.0      4.740660e+15
#
# variable               volume__variance_larger_than_standard_deviation
# id
# 0x                                                                 1.0
# aelf                                                               1.0
# aeternity                                                          1.0
# aion                                                               1.0
# ardor                                                              1.0
# ark                                                                1.0
# augur                                                              1.0
# bancor                                                             1.0
# basic-attention-token                                              1.0
# binance-coin                                                       1.0
#
# [10 rows x 17468 columns]
# variable     active_address__abs_energy  \
# id
# verge                      1.466247e+11
# veritaseum                 6.730167e+07
# waltonchain                6.250837e+07
# wanchain                   2.608398e+09
# waves                      2.660788e+10
# wax                        2.608398e+09
# zcash                      2.369382e+12
# zcoin                      2.608398e+09
# zencash                    2.608398e+09
# zilliqa                    2.354952e+08
#
# variable     active_address__absolute_sum_of_changes  \
# id
# verge                                       924126.0
# veritaseum                                   29287.0
# waltonchain                                  35426.0
# wanchain                                    259974.0
# waves                                      1686466.0
# wax                                         259974.0
# zcash                                      1906523.0
# zcoin                                       259974.0
# zencash                                     259974.0
# zilliqa                                      53307.0
#
# variable     active_address__agg_autocorrelation__f_agg_"mean"  \
# id
# verge                                                 0.859942
# veritaseum                                            0.476574
# waltonchain                                           0.215901
# wanchain                                              0.340423
# waves                                                 0.437526
# wax                                                   0.340423
# zcash                                                 0.927693
# zcoin                                                 0.340423
# zencash                                               0.340423
# zilliqa                                               0.002418
#
# variable     active_address__agg_autocorrelation__f_agg_"median"  \
# id
# verge                                                 0.860190
# veritaseum                                            0.506777
# waltonchain                                           0.187632
# wanchain                                              0.353796
# waves                                                 0.433732
# wax                                                   0.353796
# zcash                                                 0.934783
# zcoin                                                 0.353796
# zencash                                               0.353796
# zilliqa                                              -0.011676
#
# variable     active_address__agg_autocorrelation__f_agg_"var"  \
# id
# verge                                                0.005304
# veritaseum                                           0.031793
# waltonchain                                          0.009683
# wanchain                                             0.010806
# waves                                                0.008667
# wax                                                  0.010806
# zcash                                                0.001058
# zcoin                                                0.010806
# zencash                                              0.010806
# zilliqa                                              0.008752
#
# variable     active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"  \
# id
# verge                                             -5607.959918
# veritaseum                                          718.904718
# waltonchain                                         648.680162
# wanchain                                           1238.273728
# waves                                               559.067669
# wax                                                1238.273728
# zcash                                             13040.014904
# zcoin                                              1238.273728
# zencash                                            1238.273728
# zilliqa                                            1843.564286
#
# variable     active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"rvalue"  \
# id
# verge                                                 0.606455
# veritaseum                                           -0.415149
# waltonchain                                          -0.065799
# wanchain                                             -0.057492
# waves                                                 0.615942
# wax                                                  -0.057492
# zcash                                                 0.854419
# zcoin                                                -0.057492
# zencash                                              -0.057492
# zilliqa                                              -0.057492
#
# variable     active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope"  \
# id
# verge                                               172.635328
# veritaseum                                          -10.240210
# waltonchain                                          -2.887406
# wanchain                                             -6.645122
# waves                                               305.572888
# wax                                                  -6.645122
# zcash                                              1482.187523
# zcoin                                                -6.645122
# zencash                                              -6.645122
# zilliqa                                             -18.814662
#
# variable     active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"stderr"  \
# id
# verge                                                19.337607
# veritaseum                                            3.383006
# waltonchain                                           7.297838
# wanchain                                             36.135563
# waves                                                50.455748
# wax                                                  36.135563
# zcash                                               114.470386
# zcoin                                                36.135563
# zencash                                              36.135563
# zilliqa                                              77.007548
#
# variable     active_address__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept"  \
# id
# verge                                             -6691.889163
# veritaseum                                         1151.327273
# waltonchain                                        1380.833333
# wanchain                                           3664.750000
# waves                                              5259.109890
# wax                                                3664.750000
# zcash                                             21783.802198
# zcoin                                              3664.750000
# zencash                                            3664.750000
# zilliqa                                            4849.000000
#
# variable                          ...                         \
# id                                ...
# verge                             ...
# veritaseum                        ...
# waltonchain                       ...
# wanchain                          ...
# waves                             ...
# wax                               ...
# zcash                             ...
# zcoin                             ...
# zencash                           ...
# zilliqa                           ...
#
# variable     volume__time_reversal_asymmetry_statistic__lag_1  \
# id
# verge                                           -2.074784e+23
# veritaseum                                       4.439179e+16
# waltonchain                                     -9.191506e+20
# wanchain                                        -1.058998e+22
# waves                                            3.321996e+19
# wax                                             -2.832079e+21
# zcash                                           -2.296494e+21
# zcoin                                            5.917691e+19
# zencash                                         -9.596289e+19
# zilliqa                                         -1.156040e+23
#
# variable     volume__time_reversal_asymmetry_statistic__lag_2  \
# id
# verge                                           -3.804209e+23
# veritaseum                                       6.335611e+16
# waltonchain                                     -5.695716e+21
# wanchain                                        -3.770552e+21
# waves                                           -1.878305e+20
# wax                                             -2.581930e+21
# zcash                                           -3.196160e+22
# zcoin                                           -1.849818e+20
# zencash                                         -1.553048e+20
# zilliqa                                         -2.175072e+23
#
# variable     volume__time_reversal_asymmetry_statistic__lag_3  \
# id
# verge                                            1.980499e+22
# veritaseum                                       9.247988e+15
# waltonchain                                      1.131337e+21
# wanchain                                        -6.212197e+21
# waves                                           -2.444620e+20
# wax                                             -1.161918e+21
# zcash                                           -6.077346e+22
# zcoin                                           -1.092619e+20
# zencash                                         -1.018554e+20
# zilliqa                                         -1.562117e+23
#
# variable     volume__value_count__value_-inf  volume__value_count__value_0  \
# id
# verge                                    0.0                           0.0
# veritaseum                               0.0                           0.0
# waltonchain                              0.0                           0.0
# wanchain                                 0.0                           0.0
# waves                                    0.0                           0.0
# wax                                      0.0                           0.0
# zcash                                    0.0                           0.0
# zcoin                                    0.0                           0.0
# zencash                                  0.0                           0.0
# zilliqa                                  0.0                           0.0
#
# variable     volume__value_count__value_1  volume__value_count__value_inf  \
# id
# verge                                 0.0                             0.0
# veritaseum                            0.0                             0.0
# waltonchain                           0.0                             0.0
# wanchain                              0.0                             0.0
# waves                                 0.0                             0.0
# wax                                   0.0                             0.0
# zcash                                 0.0                             0.0
# zcoin                                 0.0                             0.0
# zencash                               0.0                             0.0
# zilliqa                               0.0                             0.0
#
# variable     volume__value_count__value_nan  volume__variance  \
# id
# verge                                   0.0      8.109743e+15
# veritaseum                              0.0      3.238983e+11
# waltonchain                             0.0      5.770324e+14
# wanchain                                0.0      3.997042e+14
# waves                                   0.0      3.305474e+14
# wax                                     0.0      1.313925e+14
# zcash                                   0.0      4.200767e+15
# zcoin                                   0.0      3.737511e+13
# zencash                                 0.0      1.789921e+13
# zilliqa                                 0.0      3.688235e+15
#
# variable     volume__variance_larger_than_standard_deviation
# id
# verge                                                    1.0
# veritaseum                                               1.0
# waltonchain                                              1.0
# wanchain                                                 1.0
# waves                                                    1.0
# wax                                                      1.0
# zcash                                                    1.0
# zcoin                                                    1.0
# zencash                                                  1.0
# zilliqa                                                  1.0
#
# [10 rows x 17468 columns]

# %% [markdown]
# ## Normalization
# It's clear that each feature has its own scale. So this features dataframe should be rescaled, otherwise features with larger scale will affects the distance measure higher. **normalize** function below will scale each feature to \[0, 1\] range.

# %%
def normalize(df):
    result = df.copy()
    for feature_name in df.columns:
        max_value = df[feature_name].max()
        min_value = df[feature_name].min()
        result[feature_name] = (df[feature_name] - min_value) / (max_value - min_value)
    return result

# %%
ef_norm = normalize(extracted_features)
display(ef_norm.head(10))
# Out:
# variable               active_address__abs_energy  \
# id
# 0x                                   1.282667e-06
# aelf                                 6.474441e-07
# aeternity                            2.305537e-07
# aion                                 1.695535e-07
# ardor                                5.559542e-06
# ark                                  5.559542e-06
# augur                                2.329527e-07
# bancor                               5.559542e-06
# basic-attention-token                6.394445e-07
# binance-coin                         5.071570e-05
#
# variable               active_address__absolute_sum_of_changes  \
# id
# 0x                                                    0.001078
# aelf                                                  0.000942
# aeternity                                             0.000469
# aion                                                  0.000662
# ardor                                                 0.003667
# ark                                                   0.003667
# augur                                                 0.000506
# bancor                                                0.003667
# basic-attention-token                                 0.000780
# binance-coin                                          0.004501
#
# variable               active_address__agg_autocorrelation__f_agg_"mean"  \
# id
# 0x                                                              0.130591
# aelf                                                            0.000268
# aeternity                                                       0.044632
# aion                                                            0.074524
# ardor                                                           0.369964
# ark                                                             0.369964
# augur                                                           0.380949
# bancor                                                          0.369964
# basic-attention-token                                           0.573911
# binance-coin                                                    0.021574
#
# variable               active_address__agg_autocorrelation__f_agg_"median"  \
# id
# 0x                                                              0.155094
# aelf                                                            0.041724
# aeternity                                                       0.067284
# aion                                                            0.100232
# ardor                                                           0.407461
# ark                                                             0.407461
# augur                                                           0.449468
# bancor                                                          0.407461
# basic-attention-token                                           0.615383
# binance-coin                                                    0.036515
#
# variable               active_address__agg_autocorrelation__f_agg_"var"  \
# id
# 0x                                                             0.548957
# aelf                                                           0.000000
# aeternity                                                      0.190140
# aion                                                           0.235831
# ardor                                                          0.211258
# ark                                                            0.211258
# augur                                                          0.413903
# bancor                                                         0.211258
# basic-attention-token                                          0.579813
# binance-coin                                                   0.216374
#
# variable               active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"  \
# id
# 0x                                                              0.448015
# aelf                                                            0.450795
# aeternity                                                       0.443457
# aion                                                            0.442750
# ardor                                                           0.443767
# ark                                                             0.443767
# augur                                                           0.442743
# bancor                                                          0.443767
# basic-attention-token                                           0.443631
# binance-coin                                                    0.448573
#
# variable               active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"rvalue"  \
# id
# 0x                                                              0.241708
# aelf                                                            0.266243
# aeternity                                                       0.331150
# aion                                                            0.448398
# ardor                                                           0.411932
# ark                                                             0.411932
# augur                                                           0.322140
# bancor                                                          0.411932
# basic-attention-token                                           0.363848
# binance-coin                                                    0.482434
#
# variable               active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope"  \
# id
# 0x                                                              0.292583
# aelf                                                            0.280244
# aeternity                                                       0.295880
# aion                                                            0.298905
# ardor                                                           0.298003
# ark                                                             0.298003
# augur                                                           0.297315
# bancor                                                          0.298003
# basic-attention-token                                           0.298003
# binance-coin                                                    0.313091
#
# variable               active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"stderr"  \
# id
# 0x                                                              0.014595
# aelf                                                            0.064841
# aeternity                                                       0.013170
# aion                                                            0.012658
# ardor                                                           0.022947
# ark                                                             0.022947
# augur                                                           0.005563
# bancor                                                          0.022947
# basic-attention-token                                           0.004207
# binance-coin                                                    0.200704
#
# variable               active_address__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept"  \
# id
# 0x                                                              0.321105
# aelf                                                            0.333218
# aeternity                                                       0.317506
# aion                                                            0.313462
# ardor                                                           0.317187
# ark                                                             0.317187
# augur                                                           0.312314
# bancor                                                          0.317187
# basic-attention-token                                           0.312901
# binance-coin                                                    0.340167
#
# variable                                    ...                         \
# id                                          ...
# 0x                                          ...
# aelf                                        ...
# aeternity                                   ...
# aion                                        ...
# ardor                                       ...
# ark                                         ...
# augur                                       ...
# bancor                                      ...
# basic-attention-token                       ...
# binance-coin                                ...
#
# variable               volume__time_reversal_asymmetry_statistic__lag_1  \
# id
# 0x                                                             0.117465
# aelf                                                           0.117430
# aeternity                                                      0.117471
# aion                                                           0.117469
# ardor                                                          0.117465
# ark                                                            0.117469
# augur                                                          0.117458
# bancor                                                         0.117471
# basic-attention-token                                          0.117468
# binance-coin                                                   0.117491
#
# variable               volume__time_reversal_asymmetry_statistic__lag_2  \
# id
# 0x                                                             0.712655
# aelf                                                           0.712579
# aeternity                                                      0.712657
# aion                                                           0.712656
# ardor                                                          0.712648
# ark                                                            0.712657
# augur                                                          0.712656
# bancor                                                         0.712658
# basic-attention-token                                          0.712658
# binance-coin                                                   0.712363
#
# variable               volume__time_reversal_asymmetry_statistic__lag_3  \
# id
# 0x                                                             0.897814
# aelf                                                           0.897766
# aeternity                                                      0.897813
# aion                                                           0.897814
# ardor                                                          0.897810
# ark                                                            0.897814
# augur                                                          0.897813
# bancor                                                         0.897814
# basic-attention-token                                          0.897815
# binance-coin                                                   0.897746
#
# variable               volume__value_count__value_-inf  \
# id
# 0x                                                 NaN
# aelf                                               NaN
# aeternity                                          NaN
# aion                                               NaN
# ardor                                              NaN
# ark                                                NaN
# augur                                              NaN
# bancor                                             NaN
# basic-attention-token                              NaN
# binance-coin                                       NaN
#
# variable               volume__value_count__value_0  \
# id
# 0x                                         0.000000
# aelf                                       0.000000
# aeternity                                  0.000000
# aion                                       0.000000
# ardor                                      0.095745
# ark                                        0.000000
# augur                                      0.010638
# bancor                                     0.000000
# basic-attention-token                      0.000000
# binance-coin                               0.000000
#
# variable               volume__value_count__value_1  \
# id
# 0x                                         0.000000
# aelf                                       0.000000
# aeternity                                  0.000000
# aion                                       0.000000
# ardor                                      0.012821
# ark                                        0.000000
# augur                                      0.025641
# bancor                                     0.000000
# basic-attention-token                      0.000000
# binance-coin                               0.000000
#
# variable               volume__value_count__value_inf  \
# id
# 0x                                                NaN
# aelf                                              NaN
# aeternity                                         NaN
# aion                                              NaN
# ardor                                             NaN
# ark                                               NaN
# augur                                             NaN
# bancor                                            NaN
# basic-attention-token                             NaN
# binance-coin                                      NaN
#
# variable               volume__value_count__value_nan  volume__variance  \
# id
# 0x                                                NaN          0.000033
# aelf                                              NaN          0.000273
# aeternity                                         NaN          0.000012
# aion                                              NaN          0.000006
# ardor                                             NaN          0.000021
# ark                                               NaN          0.000004
# augur                                             NaN          0.000014
# bancor                                            NaN          0.000005
# basic-attention-token                             NaN          0.000012
# binance-coin                                      NaN          0.000441
#
# variable               volume__variance_larger_than_standard_deviation
# id
# 0x                                                                 NaN
# aelf                                                               NaN
# aeternity                                                          NaN
# aion                                                               NaN
# ardor                                                              NaN
# ark                                                                NaN
# augur                                                              NaN
# bancor                                                             NaN
# basic-attention-token                                              NaN
# binance-coin                                                       NaN
#
# [10 rows x 17468 columns]

# %% [markdown]
# Some features were the same value for all coins. This may leads to appearing of **Inf**s and **NaN**s. To avoid this we should drop such features. Dropping will not affect the result because such equal features are non informative.

# %%
ef_norm = ef_norm.dropna(axis='columns', how='any')
ef_norm.shape
# Out:
# (115, 15634)

# %% [markdown]
# ## Clustering
# As previously we will use hdbscan to perform clustering. Since this time number of features is quite higher we can expect that most of coins will be considered as outliers.

# %%
tf_clusterer = hdbscan.HDBSCAN(min_cluster_size=2)
tf_labels = tf_clusterer.fit_predict(ef_norm)
ef_norm['label'] = tf_labels
for label in np.unique(tf_labels):
    if label != -1:
        print('label %d' %label)
        cl_tf = ef_norm[ef_norm['label'] == label]
        display(cl_tf)
        print('-'*40)
# Out:
# label 0
# variable   active_address__abs_energy  \
# id
# bitshares                    0.000006
# neoscoin                     0.000006
# nxt                          0.000006
#
# variable   active_address__absolute_sum_of_changes  \
# id
# bitshares                                 0.003667
# neoscoin                                  0.003667
# nxt                                       0.003667
#
# variable   active_address__agg_autocorrelation__f_agg_"mean"  \
# id
# bitshares                                           0.369964
# neoscoin                                            0.369964
# nxt                                                 0.369964
#
# variable   active_address__agg_autocorrelation__f_agg_"median"  \
# id
# bitshares                                           0.407461
# neoscoin                                            0.407461
# nxt                                                 0.407461
#
# variable   active_address__agg_autocorrelation__f_agg_"var"  \
# id
# bitshares                                          0.211258
# neoscoin                                           0.211258
# nxt                                                0.211258
#
# variable   active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"  \
# id
# bitshares                                           0.443767
# neoscoin                                            0.443767
# nxt                                                 0.443767
#
# variable   active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"rvalue"  \
# id
# bitshares                                           0.411932
# neoscoin                                            0.411932
# nxt                                                 0.411932
#
# variable   active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope"  \
# id
# bitshares                                           0.298003
# neoscoin                                            0.298003
# nxt                                                 0.298003
#
# variable   active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"stderr"  \
# id
# bitshares                                           0.022947
# neoscoin                                            0.022947
# nxt                                                 0.022947
#
# variable   active_address__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept"  \
# id
# bitshares                                           0.317187
# neoscoin                                            0.317187
# nxt                                                 0.317187
#
# variable   ...    volume__sum_values  volume__symmetry_looking__r_0.05  \
# id         ...
# bitshares  ...              0.006706                               1.0
# neoscoin   ...              0.000093                               1.0
# nxt        ...              0.004531                               1.0
#
# variable   volume__symmetry_looking__r_0.1  \
# id
# bitshares                              1.0
# neoscoin                               1.0
# nxt                                    1.0
#
# variable   volume__time_reversal_asymmetry_statistic__lag_1  \
# id
# bitshares                                          0.117462
# neoscoin                                           0.117470
# nxt                                                0.117499
#
# variable   volume__time_reversal_asymmetry_statistic__lag_2  \
# id
# bitshares                                          0.712534
# neoscoin                                           0.712657
# nxt                                                0.712691
#
# variable   volume__time_reversal_asymmetry_statistic__lag_3  \
# id
# bitshares                                          0.897765
# neoscoin                                           0.897814
# nxt                                                0.897811
#
# variable   volume__value_count__value_0  volume__value_count__value_1  \
# id
# bitshares                           0.0                           0.0
# neoscoin                            0.0                           0.0
# nxt                                 0.0                           0.0
#
# variable   volume__variance  label
# id
# bitshares      1.005685e-04      0
# neoscoin       4.762230e-08      0
# nxt            1.321656e-04      0
#
# [3 rows x 15635 columns]
# ----------------------------------------
# label 1
# variable       active_address__abs_energy  \
# id
# bitsend                          0.000006
# crown                            0.000006
# emercoin                         0.000006
# exclusivecoin                    0.000006
# korecoin                         0.000006
# monetaryunit                     0.000006
#
# variable       active_address__absolute_sum_of_changes  \
# id
# bitsend                                       0.003667
# crown                                         0.003667
# emercoin                                      0.003667
# exclusivecoin                                 0.003667
# korecoin                                      0.003667
# monetaryunit                                  0.003667
#
# variable       active_address__agg_autocorrelation__f_agg_"mean"  \
# id
# bitsend                                                 0.369964
# crown                                                   0.369964
# emercoin                                                0.369964
# exclusivecoin                                           0.369964
# korecoin                                                0.369964
# monetaryunit                                            0.369964
#
# variable       active_address__agg_autocorrelation__f_agg_"median"  \
# id
# bitsend                                                 0.407461
# crown                                                   0.407461
# emercoin                                                0.407461
# exclusivecoin                                           0.407461
# korecoin                                                0.407461
# monetaryunit                                            0.407461
#
# variable       active_address__agg_autocorrelation__f_agg_"var"  \
# id
# bitsend                                                0.211258
# crown                                                  0.211258
# emercoin                                               0.211258
# exclusivecoin                                          0.211258
# korecoin                                               0.211258
# monetaryunit                                           0.211258
#
# variable       active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"  \
# id
# bitsend                                                 0.443767
# crown                                                   0.443767
# emercoin                                                0.443767
# exclusivecoin                                           0.443767
# korecoin                                                0.443767
# monetaryunit                                            0.443767
#
# variable       active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"rvalue"  \
# id
# bitsend                                                 0.411932
# crown                                                   0.411932
# emercoin                                                0.411932
# exclusivecoin                                           0.411932
# korecoin                                                0.411932
# monetaryunit                                            0.411932
#
# variable       active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope"  \
# id
# bitsend                                                 0.298003
# crown                                                   0.298003
# emercoin                                                0.298003
# exclusivecoin                                           0.298003
# korecoin                                                0.298003
# monetaryunit                                            0.298003
#
# variable       active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"stderr"  \
# id
# bitsend                                                 0.022947
# crown                                                   0.022947
# emercoin                                                0.022947
# exclusivecoin                                           0.022947
# korecoin                                                0.022947
# monetaryunit                                            0.022947
#
# variable       active_address__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept"  \
# id
# bitsend                                                 0.317187
# crown                                                   0.317187
# emercoin                                                0.317187
# exclusivecoin                                           0.317187
# korecoin                                                0.317187
# monetaryunit                                            0.317187
#
# variable       ...    volume__sum_values  volume__symmetry_looking__r_0.05  \
# id             ...
# bitsend        ...              0.000092                               1.0
# crown          ...              0.000024                               1.0
# emercoin       ...              0.000265                               1.0
# exclusivecoin  ...              0.000074                               1.0
# korecoin       ...              0.000122                               1.0
# monetaryunit   ...              0.000106                               1.0
#
# variable       volume__symmetry_looking__r_0.1  \
# id
# bitsend                                    1.0
# crown                                      1.0
# emercoin                                   1.0
# exclusivecoin                              1.0
# korecoin                                   1.0
# monetaryunit                               1.0
#
# variable       volume__time_reversal_asymmetry_statistic__lag_1  \
# id
# bitsend                                                0.117470
# crown                                                  0.117470
# emercoin                                               0.117469
# exclusivecoin                                          0.117470
# korecoin                                               0.117470
# monetaryunit                                           0.117470
#
# variable       volume__time_reversal_asymmetry_statistic__lag_2  \
# id
# bitsend                                                0.712657
# crown                                                  0.712657
# emercoin                                               0.712657
# exclusivecoin                                          0.712657
# korecoin                                               0.712657
# monetaryunit                                           0.712657
#
# variable       volume__time_reversal_asymmetry_statistic__lag_3  \
# id
# bitsend                                                0.897814
# crown                                                  0.897814
# emercoin                                               0.897814
# exclusivecoin                                          0.897814
# korecoin                                               0.897814
# monetaryunit                                           0.897814
#
# variable       volume__value_count__value_0  volume__value_count__value_1  \
# id
# bitsend                            0.191489                      0.448718
# crown                              1.000000                      0.679487
# emercoin                           0.127660                      0.076923
# exclusivecoin                      0.031915                      0.141026
# korecoin                           0.542553                      1.000000
# monetaryunit                       0.234043                      0.230769
#
# variable       volume__variance  label
# id
# bitsend            1.530308e-07      1
# crown              1.875903e-09      1
# emercoin           4.712445e-07      1
# exclusivecoin      7.142969e-08      1
# korecoin           1.493741e-07      1
# monetaryunit       8.807120e-08      1
#
# [6 rows x 15635 columns]
# ----------------------------------------
# label 2
# variable  active_address__abs_energy  active_address__absolute_sum_of_changes  \
# id
# diamond                     0.000006                                 0.003667
# reddcoin                    0.000006                                 0.003667
#
# variable  active_address__agg_autocorrelation__f_agg_"mean"  \
# id
# diamond                                            0.369964
# reddcoin                                           0.369964
#
# variable  active_address__agg_autocorrelation__f_agg_"median"  \
# id
# diamond                                            0.407461
# reddcoin                                           0.407461
#
# variable  active_address__agg_autocorrelation__f_agg_"var"  \
# id
# diamond                                           0.211258
# reddcoin                                          0.211258
#
# variable  active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"  \
# id
# diamond                                            0.443767
# reddcoin                                           0.443767
#
# variable  active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"rvalue"  \
# id
# diamond                                            0.411932
# reddcoin                                           0.411932
#
# variable  active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope"  \
# id
# diamond                                            0.298003
# reddcoin                                           0.298003
#
# variable  active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"stderr"  \
# id
# diamond                                            0.022947
# reddcoin                                           0.022947
#
# variable  active_address__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept"  \
# id
# diamond                                            0.317187
# reddcoin                                           0.317187
#
# variable  ...    volume__sum_values  volume__symmetry_looking__r_0.05  \
# id        ...
# diamond   ...              0.000025                               1.0
# reddcoin  ...              0.001678                               1.0
#
# variable  volume__symmetry_looking__r_0.1  \
# id
# diamond                               1.0
# reddcoin                              1.0
#
# variable  volume__time_reversal_asymmetry_statistic__lag_1  \
# id
# diamond                                           0.117470
# reddcoin                                          0.117467
#
# variable  volume__time_reversal_asymmetry_statistic__lag_2  \
# id
# diamond                                           0.712657
# reddcoin                                          0.712652
#
# variable  volume__time_reversal_asymmetry_statistic__lag_3  \
# id
# diamond                                           0.897814
# reddcoin                                          0.897813
#
# variable  volume__value_count__value_0  volume__value_count__value_1  \
# id
# diamond                            0.0                      0.012821
# reddcoin                           0.0                      0.000000
#
# variable  volume__variance  label
# id
# diamond       8.215973e-09      2
# reddcoin      1.419455e-05      2
#
# [2 rows x 15635 columns]
# ----------------------------------------
# label 3
# variable         active_address__abs_energy  \
# id
# bitcoin-diamond                    0.000006
# wax                                0.000006
#
# variable         active_address__absolute_sum_of_changes  \
# id
# bitcoin-diamond                                 0.003667
# wax                                             0.003667
#
# variable         active_address__agg_autocorrelation__f_agg_"mean"  \
# id
# bitcoin-diamond                                           0.369964
# wax                                                       0.369964
#
# variable         active_address__agg_autocorrelation__f_agg_"median"  \
# id
# bitcoin-diamond                                           0.407461
# wax                                                       0.407461
#
# variable         active_address__agg_autocorrelation__f_agg_"var"  \
# id
# bitcoin-diamond                                          0.211258
# wax                                                      0.211258
#
# variable         active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"  \
# id
# bitcoin-diamond                                           0.443767
# wax                                                       0.443767
#
# variable         active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"rvalue"  \
# id
# bitcoin-diamond                                           0.411932
# wax                                                       0.411932
#
# variable         active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope"  \
# id
# bitcoin-diamond                                           0.298003
# wax                                                       0.298003
#
# variable         active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"stderr"  \
# id
# bitcoin-diamond                                           0.022947
# wax                                                       0.022947
#
# variable         active_address__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept"  \
# id
# bitcoin-diamond                                           0.317187
# wax                                                       0.317187
#
# variable         ...    volume__sum_values  volume__symmetry_looking__r_0.05  \
# id               ...
# bitcoin-diamond  ...              0.001480                               1.0
# wax              ...              0.000628                               1.0
#
# variable         volume__symmetry_looking__r_0.1  \
# id
# bitcoin-diamond                              1.0
# wax                                          1.0
#
# variable         volume__time_reversal_asymmetry_statistic__lag_1  \
# id
# bitcoin-diamond                                          0.119593
# wax                                                      0.117456
#
# variable         volume__time_reversal_asymmetry_statistic__lag_2  \
# id
# bitcoin-diamond                                          0.712634
# wax                                                      0.712648
#
# variable         volume__time_reversal_asymmetry_statistic__lag_3  \
# id
# bitcoin-diamond                                          0.897787
# wax                                                      0.897813
#
# variable         volume__value_count__value_0  volume__value_count__value_1  \
# id
# bitcoin-diamond                           0.0                           0.0
# wax                                       0.0                           0.0
#
# variable         volume__variance  label
# id
# bitcoin-diamond          0.000306      3
# wax                      0.000012      3
#
# [2 rows x 15635 columns]
# ----------------------------------------
# label 4
# variable              active_address__abs_energy  \
# id
# ardor                                   0.000006
# ark                                     0.000006
# cryptonex                               0.000006
# cybermiles                              0.000006
# decentraland                            0.000006
# digixdao                                0.000006
# elastos                                 0.000006
# enigma-project                          0.000006
# factom                                  0.000006
# gifto                                   0.000006
# golem-network-tokens                    0.000006
# gxchain                                 0.000006
# iota                                    0.000006
# komodo                                  0.000006
# monaco                                  0.000006
# nano                                    0.000006
# nebulas-token                           0.000006
# nuls                                    0.000006
# ontology                                0.000006
# qtum                                    0.000006
# smartcash                               0.000006
# stratis                                 0.000006
# zcoin                                   0.000006
# zencash                                 0.000006
#
# variable              active_address__absolute_sum_of_changes  \
# id
# ardor                                                0.003667
# ark                                                  0.003667
# cryptonex                                            0.003667
# cybermiles                                           0.003667
# decentraland                                         0.003667
# digixdao                                             0.003667
# elastos                                              0.003667
# enigma-project                                       0.003667
# factom                                               0.003667
# gifto                                                0.003667
# golem-network-tokens                                 0.003667
# gxchain                                              0.003667
# iota                                                 0.003667
# komodo                                               0.003667
# monaco                                               0.003667
# nano                                                 0.003667
# nebulas-token                                        0.003667
# nuls                                                 0.003667
# ontology                                             0.003667
# qtum                                                 0.003667
# smartcash                                            0.003667
# stratis                                              0.003667
# zcoin                                                0.003667
# zencash                                              0.003667
#
# variable              active_address__agg_autocorrelation__f_agg_"mean"  \
# id
# ardor                                                          0.369964
# ark                                                            0.369964
# cryptonex                                                      0.369964
# cybermiles                                                     0.369964
# decentraland                                                   0.369964
# digixdao                                                       0.369964
# elastos                                                        0.369964
# enigma-project                                                 0.369964
# factom                                                         0.369964
# gifto                                                          0.369964
# golem-network-tokens                                           0.369964
# gxchain                                                        0.369964
# iota                                                           0.369964
# komodo                                                         0.369964
# monaco                                                         0.369964
# nano                                                           0.369964
# nebulas-token                                                  0.369964
# nuls                                                           0.369964
# ontology                                                       0.369964
# qtum                                                           0.369964
# smartcash                                                      0.369964
# stratis                                                        0.369964
# zcoin                                                          0.369964
# zencash                                                        0.369964
#
# variable              active_address__agg_autocorrelation__f_agg_"median"  \
# id
# ardor                                                          0.407461
# ark                                                            0.407461
# cryptonex                                                      0.407461
# cybermiles                                                     0.407461
# decentraland                                                   0.407461
# digixdao                                                       0.407461
# elastos                                                        0.407461
# enigma-project                                                 0.407461
# factom                                                         0.407461
# gifto                                                          0.407461
# golem-network-tokens                                           0.407461
# gxchain                                                        0.407461
# iota                                                           0.407461
# komodo                                                         0.407461
# monaco                                                         0.407461
# nano                                                           0.407461
# nebulas-token                                                  0.407461
# nuls                                                           0.407461
# ontology                                                       0.407461
# qtum                                                           0.407461
# smartcash                                                      0.407461
# stratis                                                        0.407461
# zcoin                                                          0.407461
# zencash                                                        0.407461
#
# variable              active_address__agg_autocorrelation__f_agg_"var"  \
# id
# ardor                                                         0.211258
# ark                                                           0.211258
# cryptonex                                                     0.211258
# cybermiles                                                    0.211258
# decentraland                                                  0.211258
# digixdao                                                      0.211258
# elastos                                                       0.211258
# enigma-project                                                0.211258
# factom                                                        0.211258
# gifto                                                         0.211258
# golem-network-tokens                                          0.211258
# gxchain                                                       0.211258
# iota                                                          0.211258
# komodo                                                        0.211258
# monaco                                                        0.211258
# nano                                                          0.211258
# nebulas-token                                                 0.211258
# nuls                                                          0.211258
# ontology                                                      0.211258
# qtum                                                          0.211258
# smartcash                                                     0.211258
# stratis                                                       0.211258
# zcoin                                                         0.211258
# zencash                                                       0.211258
#
# variable              active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"  \
# id
# ardor                                                          0.443767
# ark                                                            0.443767
# cryptonex                                                      0.443767
# cybermiles                                                     0.443767
# decentraland                                                   0.443767
# digixdao                                                       0.443767
# elastos                                                        0.443767
# enigma-project                                                 0.443767
# factom                                                         0.443767
# gifto                                                          0.443767
# golem-network-tokens                                           0.443767
# gxchain                                                        0.443767
# iota                                                           0.443767
# komodo                                                         0.443767
# monaco                                                         0.443767
# nano                                                           0.443767
# nebulas-token                                                  0.443767
# nuls                                                           0.443767
# ontology                                                       0.443767
# qtum                                                           0.443767
# smartcash                                                      0.443767
# stratis                                                        0.443767
# zcoin                                                          0.443767
# zencash                                                        0.443767
#
# variable              active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"rvalue"  \
# id
# ardor                                                          0.411932
# ark                                                            0.411932
# cryptonex                                                      0.411932
# cybermiles                                                     0.411932
# decentraland                                                   0.411932
# digixdao                                                       0.411932
# elastos                                                        0.411932
# enigma-project                                                 0.411932
# factom                                                         0.411932
# gifto                                                          0.411932
# golem-network-tokens                                           0.411932
# gxchain                                                        0.411932
# iota                                                           0.411932
# komodo                                                         0.411932
# monaco                                                         0.411932
# nano                                                           0.411932
# nebulas-token                                                  0.411932
# nuls                                                           0.411932
# ontology                                                       0.411932
# qtum                                                           0.411932
# smartcash                                                      0.411932
# stratis                                                        0.411932
# zcoin                                                          0.411932
# zencash                                                        0.411932
#
# variable              active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope"  \
# id
# ardor                                                          0.298003
# ark                                                            0.298003
# cryptonex                                                      0.298003
# cybermiles                                                     0.298003
# decentraland                                                   0.298003
# digixdao                                                       0.298003
# elastos                                                        0.298003
# enigma-project                                                 0.298003
# factom                                                         0.298003
# gifto                                                          0.298003
# golem-network-tokens                                           0.298003
# gxchain                                                        0.298003
# iota                                                           0.298003
# komodo                                                         0.298003
# monaco                                                         0.298003
# nano                                                           0.298003
# nebulas-token                                                  0.298003
# nuls                                                           0.298003
# ontology                                                       0.298003
# qtum                                                           0.298003
# smartcash                                                      0.298003
# stratis                                                        0.298003
# zcoin                                                          0.298003
# zencash                                                        0.298003
#
# variable              active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"stderr"  \
# id
# ardor                                                          0.022947
# ark                                                            0.022947
# cryptonex                                                      0.022947
# cybermiles                                                     0.022947
# decentraland                                                   0.022947
# digixdao                                                       0.022947
# elastos                                                        0.022947
# enigma-project                                                 0.022947
# factom                                                         0.022947
# gifto                                                          0.022947
# golem-network-tokens                                           0.022947
# gxchain                                                        0.022947
# iota                                                           0.022947
# komodo                                                         0.022947
# monaco                                                         0.022947
# nano                                                           0.022947
# nebulas-token                                                  0.022947
# nuls                                                           0.022947
# ontology                                                       0.022947
# qtum                                                           0.022947
# smartcash                                                      0.022947
# stratis                                                        0.022947
# zcoin                                                          0.022947
# zencash                                                        0.022947
#
# variable              active_address__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept"  \
# id
# ardor                                                          0.317187
# ark                                                            0.317187
# cryptonex                                                      0.317187
# cybermiles                                                     0.317187
# decentraland                                                   0.317187
# digixdao                                                       0.317187
# elastos                                                        0.317187
# enigma-project                                                 0.317187
# factom                                                         0.317187
# gifto                                                          0.317187
# golem-network-tokens                                           0.317187
# gxchain                                                        0.317187
# iota                                                           0.317187
# komodo                                                         0.317187
# monaco                                                         0.317187
# nano                                                           0.317187
# nebulas-token                                                  0.317187
# nuls                                                           0.317187
# ontology                                                       0.317187
# qtum                                                           0.317187
# smartcash                                                      0.317187
# stratis                                                        0.317187
# zcoin                                                          0.317187
# zencash                                                        0.317187
#
# variable              ...    volume__sum_values  \
# id                    ...
# ardor                 ...              0.001493
# ark                   ...              0.000871
# cryptonex             ...              0.000098
# cybermiles            ...              0.002618
# decentraland          ...              0.001773
# digixdao              ...              0.001666
# ...
# decentraland                                                  0.712653
# digixdao                                                      0.712639
# elastos                                                       0.712656
# enigma-project                                                0.712653
# factom                                                        0.712656
# gifto                                                         0.712656
# golem-network-tokens                                          0.712630
# gxchain                                                       0.712657
# iota                                                          0.709569
# komodo                                                        0.712657
# monaco                                                        0.712430
# nano                                                          0.712640
# nebulas-token                                                 0.712657
# nuls                                                          0.712682
# ontology                                                      0.712694
# qtum                                                          0.695224
# smartcash                                                     0.712657
# stratis                                                       0.712655
# zcoin                                                         0.712656
# zencash                                                       0.712657
#
# variable              volume__time_reversal_asymmetry_statistic__lag_3  \
# id
# ardor                                                         0.897810
# ark                                                           0.897814
# cryptonex                                                     0.897814
# cybermiles                                                    0.897813
# decentraland                                                  0.897813
# digixdao                                                      0.897814
# elastos                                                       0.897814
# enigma-project                                                0.897813
# factom                                                        0.897814
# gifto                                                         0.897814
# golem-network-tokens                                          0.897813
# gxchain                                                       0.897814
# iota                                                          0.893221
# komodo                                                        0.897814
# monaco                                                        0.897767
# nano                                                          0.897787
# nebulas-token                                                 0.897814
# nuls                                                          0.897834
# ontology                                                      0.897885
# qtum                                                          0.896367
# smartcash                                                     0.897814
# stratis                                                       0.897814
# zcoin                                                         0.897814
# zencash                                                       0.897814
#
# variable              volume__value_count__value_0  \
# id
# ardor                                     0.095745
# ark                                       0.000000
# cryptonex                                 0.000000
# cybermiles                                0.000000
# decentraland                              0.000000
# digixdao                                  0.000000
# elastos                                   0.000000
# enigma-project                            0.000000
# factom                                    0.000000
# gifto                                     0.000000
# golem-network-tokens                      0.000000
# gxchain                                   0.000000
# iota                                      0.000000
# komodo                                    0.000000
# monaco                                    0.000000
# nano                                      0.000000
# nebulas-token                             0.000000
# nuls                                      0.000000
# ontology                                  0.000000
# qtum                                      0.000000
# smartcash                                 0.000000
# stratis                                   0.000000
# zcoin                                     0.000000
# zencash                                   0.000000
#
# variable              volume__value_count__value_1  volume__variance  label
# id
# ardor                                     0.012821      2.132189e-05      4
# ark                                       0.000000      4.139766e-06      4
# cryptonex                                 0.000000      6.604458e-08      4
# cybermiles                                0.000000      7.631944e-05      4
# decentraland                              0.000000      3.272810e-05      4
# digixdao                                  0.000000      2.762521e-05      4
# elastos                                   0.000000      2.666893e-05      4
# enigma-project                            0.000000      1.422224e-05      4
# factom                                    0.000000      2.666893e-05      4
# gifto                                     0.000000      2.666893e-05      4
# golem-network-tokens                      0.000000      7.938936e-05      4
# gxchain                                   0.000000      5.459084e-06      4
# iota                                      0.000000      3.395559e-03      4
# komodo                                    0.000000      4.995898e-06      4
# monaco                                    0.000000      1.669816e-04      4
# nano                                      0.000000      8.882414e-05      4
# nebulas-token                             0.000000      2.194576e-05      4
# nuls                                      0.000000      7.957878e-05      4
# ontology                                  0.000000      3.318437e-04      4
# qtum                                      0.000000      8.621789e-03      4
# smartcash                                 0.000000      7.924453e-08      4
# stratis                                   0.000000      3.452054e-05      4
# zcoin                                     0.000000      3.480459e-06      4
# zencash                                   0.000000      1.666803e-06      4
#
# [24 rows x 15635 columns]
# ----------------------------------------
# label 5
# variable          active_address__abs_energy  \
# id
# bitcoin-private                     0.000006
# hshare                              0.000006
# moac                                0.000006
# polymath-network                    0.000006
# wanchain                            0.000006
#
# variable          active_address__absolute_sum_of_changes  \
# id
# bitcoin-private                                  0.003667
# hshare                                           0.003667
# moac                                             0.003667
# polymath-network                                 0.003667
# wanchain                                         0.003667
#
# variable          active_address__agg_autocorrelation__f_agg_"mean"  \
# id
# bitcoin-private                                            0.369964
# hshare                                                     0.369964
# moac                                                       0.369964
# polymath-network                                           0.369964
# wanchain                                                   0.369964
#
# variable          active_address__agg_autocorrelation__f_agg_"median"  \
# id
# bitcoin-private                                            0.407461
# hshare                                                     0.407461
# moac                                                       0.407461
# polymath-network                                           0.407461
# wanchain                                                   0.407461
#
# variable          active_address__agg_autocorrelation__f_agg_"var"  \
# id
# bitcoin-private                                           0.211258
# hshare                                                    0.211258
# moac                                                      0.211258
# polymath-network                                          0.211258
# wanchain                                                  0.211258
#
# variable          active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"  \
# id
# bitcoin-private                                            0.443767
# hshare                                                     0.443767
# moac                                                       0.443767
# polymath-network                                           0.443767
# wanchain                                                   0.443767
#
# variable          active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"rvalue"  \
# id
# bitcoin-private                                            0.411932
# hshare                                                     0.411932
# moac                                                       0.411932
# polymath-network                                           0.411932
# wanchain                                                   0.411932
#
# variable          active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope"  \
# id
# bitcoin-private                                            0.298003
# hshare                                                     0.298003
# moac                                                       0.298003
# polymath-network                                           0.298003
# wanchain                                                   0.298003
#
# variable          active_address__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"stderr"  \
# id
# bitcoin-private                                            0.022947
# hshare                                                     0.022947
# moac                                                       0.022947
# polymath-network                                           0.022947
# wanchain                                                   0.022947
#
# variable          active_address__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept"  \
# id
# bitcoin-private                                            0.317187
# hshare                                                     0.317187
# moac                                                       0.317187
# polymath-network                                           0.317187
# wanchain                                                   0.317187
#
# variable          ...    volume__sum_values  volume__symmetry_looking__r_0.05  \
# id                ...
# bitcoin-private   ...              0.000035                               0.0
# hshare            ...              0.008126                               0.0
# moac              ...              0.000060                               0.0
# polymath-network  ...              0.000306                               1.0
# wanchain          ...              0.000765                               1.0
#
# variable          volume__symmetry_looking__r_0.1  \
# id
# bitcoin-private                               1.0
# hshare                                        1.0
# moac                                          1.0
# polymath-network                              1.0
# wanchain                                      1.0
#
# variable          volume__time_reversal_asymmetry_statistic__lag_1  \
# id
# bitcoin-private                                           0.117470
# hshare                                                    0.117411
# moac                                                      0.117470
# polymath-network                                          0.117470
# wanchain                                                  0.117420
#
# variable          volume__time_reversal_asymmetry_statistic__lag_2  \
# id
# bitcoin-private                                           0.712657
# hshare                                                    0.712611
# moac                                                      0.712657
# polymath-network                                          0.712657
# wanchain                                                  0.712644
#
# variable          volume__time_reversal_asymmetry_statistic__lag_3  \
# id
# bitcoin-private                                           0.897814
# hshare                                                    0.897814
# moac                                                      0.897814
# polymath-network                                          0.897814
# wanchain                                                  0.897807
#
# variable          volume__value_count__value_0  volume__value_count__value_1  \
# id
# bitcoin-private                            0.0                           0.0
# hshare                                     0.0                           0.0
# moac                                       0.0                           0.0
# polymath-network                           0.0                           0.0
# wanchain                                   0.0                           0.0
#
# variable          volume__variance  label
# id
# bitcoin-private       2.214374e-08      5
# hshare                3.221602e-04      5
# moac                  2.658076e-07      5
# polymath-network      2.309527e-06      5
# wanchain              3.722166e-05      5
#
# [5 rows x 15635 columns]
# ----------------------------------------

# %% [markdown]
# ## Conclusions
# As it was expected, most of coins were considered outliers. The main reason for such behavior is very high dimensionality of features space. Actually we have ~150 points, each having it's own value for every of ~15k coordinates. And our goal is to find points that close enough in this rarefied space to be considered **cluster**. On the other hand this means that founded clusters represent coins that very similar.
#
# Part II of final report was successfully completed. Two different approaches were demonstrated. Both approaches, manual features extracion and automated feature extraction with tsfresh library, gave different interesting results as it was initially expected.
#
# Next step is performing clustering with taking into account different market states.
